# %%
import pandas as pd

# %%
df = pd.read_parquet(
    "F:\PyTorch_GPU\\vessel_trajectory_prediction\Data\\region_1_q1_merged_renamed.parquet"
)
df.head(10)
# Out:
#                  Time       MMSI  Longitude   Latitude       SOG  NAVSTATUS  \
# 0 2025-01-01 00:00:01  367637980 -90.419240  29.996450  0.300000       12.0
# 1 2025-01-01 00:10:01  367637980 -90.419341  29.996455  0.283333       12.0
# 2 2025-01-01 00:20:01  367637980 -90.419441  29.996460  0.266667       12.0
# 3 2025-01-01 00:30:01  367637980 -90.419542  29.996465  0.250000       12.0
# 4 2025-01-01 00:40:01  367637980 -90.419642  29.996470  0.233333       12.0
# 5 2025-01-01 00:50:01  367637980 -90.419743  29.996475  0.216667       12.0
# 6 2025-01-01 01:00:01  367637980 -90.419843  29.996480  0.200000       12.0
# 7 2025-01-01 01:10:01  367637980 -90.419944  29.996485  0.183333       12.0
# 8 2025-01-01 01:20:01  367637980 -90.420044  29.996490  0.166667       12.0
# 9 2025-01-01 01:30:01  367637980 -90.420145  29.996495  0.150000       12.0
#
#           COG VESSEL_TYPE   final_voyage_id  is_interpolated
# 0  204.000000          31  367637980_0_c0.0            False
# ...

# %%
df.shape
# Out:
# (17574133, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17574133 entries, 0 to 17574132
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Time             datetime64[ns]
#  1   MMSI             int64
#  2   Longitude        float64
#  3   Latitude         float64
#  4   SOG              float64
#  5   NAVSTATUS        float64
#  6   COG              float64
#  7   VESSEL_TYPE      object
#  8   final_voyage_id  object
#  9   is_interpolated  bool
# dtypes: bool(1), datetime64[ns](1), float64(5), int64(1), object(2)
# memory usage: 1.2+ GB
